# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

date_rng = pd.date_range(start='2023-01-01', end='2024-12-31', freq='D')

trend = np.linspace(0, 100, len(date_rng))

seasonality = 10 * np.sin(np.linspace(0, 3.14 * 2, len(date_rng)))

noise = np.random.normal(0, 2, len(date_rng))

data = trend + seasonality + noise

df = pd.DataFrame(data, columns=['value'], index=date_rng)

plt.figure(figsize=(10, 6))
plt.plot(df.index, df['value'], label='Generated Time Series', color='red')
plt.title('Generated Time Series Data')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

print(df.head())
# Out:
#                value
# 2023-01-01 -1.807709
# 2023-01-02  0.279572
# 2023-01-03  0.851762
# 2023-01-04 -0.680575
# 2023-01-05 -0.782116
